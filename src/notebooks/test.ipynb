# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('1', 1542069637796, 66, 'free', None, None, '514', 'Harrisburg-Carlisle, PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  ('3', 1542071549796, 51, 'free', None, None, '510', 'Houston-The Woodlands-Sugar Land, TX', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  ('4', 1542079142796, 9, 'free', None, None, '379', 'Eureka-Arcata-Fortuna, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'),
#  ('5', 1542081112796, 49, 'free', None, None, '506', 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  ('8', 1542085206796, 94, 'free', None, None, '492', 'Ogden-Clearfield, UT', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0')]

# %%
# %sql SELECT location, COUNT(location) FROM songplays GROUP BY location ORDER BY COUNT(location) DESC;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 31 rows affected.
# [('Atlanta-Sandy Springs-Roswell, GA', 105),
#  ('Waterloo-Cedar Falls, IA', 86),
#  ('Lansing-East Lansing, MI', 75),
#  ('Winston-Salem, NC', 67),
#  ('San Francisco-Oakland-Hayward, CA', 51),
#  ('Marinette, WI-MI', 30),
#  ('Portland-South Portland, ME', 12),
#  ('Birmingham-Hoover, AL', 9),
#  ('San Jose-Sunnyvale-Santa Clara, CA', 8),
#  ('Harrisburg-Carlisle, PA', 8),
#  ('New York-Newark-Jersey City, NY-NJ-PA', 8),
#  ('Salinas, CA', 8),
#  ('Augusta-Richmond County, GA-SC', 7),
#  ('Tampa-St. Petersburg-Clearwater, FL', 7),
#  ('Seattle-Tacoma-Bellevue, WA', 6),
#  ('Minneapolis-St. Paul-Bloomington, MN-WI', 5),
#  ('Chicago-Naperville-Elgin, IL-IN-WI', 5),
#  ('New Orleans-Metairie, LA', 4),
#  ('Nashville-Davidson--Murfreesboro--Franklin, TN', 4),
#  ('New Haven-Milford, CT', 3),
#  ('Eureka-Arcata-Fortuna, CA', 3),
#  ('Red Bluff, CA', 3),
#  ('Santa Rosa, CA', 3),
# ...

# %%
# %sql SELECT * FROM songplays where artist_id IS NOT NULL AND song_id IS NOT NULL;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT user_id, COUNT(user_id) FROM songplays GROUP BY user_id ORDER BY COUNT(user_id) DESC;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 39 rows affected.
# [(29, 103),
#  (44, 86),
#  (97, 75),
#  (95, 67),
#  (49, 51),
#  (25, 30),
#  (80, 12),
#  (16, 9),
#  (37, 8),
#  (66, 8),
#  (58, 7),
#  (76, 6),
#  (55, 5),
#  (15, 5),
#  (67, 4),
#  (26, 4),
#  (42, 4),
#  (101, 4),
#  (30, 4),
#  (60, 4),
#  (9, 3),
#  (32, 3),
#  (73, 3),
#  (50, 3),
#  (63, 3),
#  (52, 2),
#  (88, 2),
#  (14, 2),
#  (83, 2),
#  (6, 2),
#  (86, 2),
#  (54, 2),
#  (69, 1),
#  (35, 1),
#  (12, 1),
#  (85, 1),
#  (51, 1),
#  (94, 1),
#  (22, 1)]

# %%
# %sql SELECT u.first_name, u.last_name, u.user_id, COUNT(u.user_id) FROM users as u JOIN songplays as s ON u.user_id=s.user_id GROUP BY u.user_id ORDER BY COUNT(u.user_id) DESC;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 39 rows affected.
# [('Jacqueline', 'Lynch', 29, 103),
#  ('Aleena', 'Kirby', 44, 86),
#  ('Kate', 'Harrell', 97, 75),
#  ('Sara', 'Johnson', 95, 67),
#  ('Chloe', 'Cuevas', 49, 51),
#  ('Jayden', 'Graves', 25, 30),
#  ('Tegan', 'Levine', 80, 12),
#  ('Rylan', 'George', 16, 9),
#  ('Jordan', 'Hicks', 37, 8),
#  ('Kevin', 'Arellano', 66, 8),
#  ('Emily', 'Benson', 58, 7),
#  ('Jayden', 'Duffy', 76, 6),
#  ('Lily', 'Koch', 15, 5),
#  ('Martin', 'Johnson', 55, 5),
#  ('Jayden', 'Fox', 101, 4),
#  ('Devin', 'Larson', 60, 4),
#  ('Avery', 'Watkins', 30, 4),
#  ('Colm', 'Santana', 67, 4),
#  ('Ryan', 'Smith', 26, 4),
#  ('Harper', 'Barrett', 42, 4),
#  ('Wyatt', 'Scott', 9, 3),
#  ('Ava', 'Robinson', 50, 3),
#  ('Jacob', 'Klein', 73, 3),
#  ('Ayla', 'Johnson', 63, 3),
#  ('Lily', 'Burns', 32, 3),
#  ('Mohammad', 'Rodriguez', 88, 2),
#  ('Stefany', 'White', 83, 2),
#  ('Cecilia', 'Owens', 6, 2),
#  ('Aiden', 'Hess', 86, 2),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(40, 'Tucker', 'Garrison', 'M', 'free'),
#  (56, 'Cienna', 'Freeman', 'F', 'free'),
#  (72, 'Hayden', 'Brock', 'F', 'paid'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (9, 'Wyatt', 'Scott', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, Decimal('484.62322')),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, Decimal('207.77751')),
#  ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, Decimal('313.12934')),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, Decimal('269.58322')),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, Decimal('156.39465'))]

# %%
# %sql SELECT * FROM songs;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, Decimal('484.62322')),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, Decimal('207.77751')),
#  ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, Decimal('313.12934')),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, Decimal('269.58322')),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, Decimal('156.39465')),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, Decimal('225.09669')),
#  ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, Decimal('186.48771')),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, Decimal('168.25424')),
# ...

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', Decimal('27.94017'), Decimal('-82.32547')),
#  ('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', Decimal('40.82624'), Decimal('-74.47995')),
#  ('ARGUVEV1187B98BA17', 'Sierra Maestra', '', None, None),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', Decimal('49.80388'), Decimal('15.47491')),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', Decimal('40.73197'), Decimal('-74.17418'))]

# %%
# %sql SELECT * FROM artists;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 69 rows affected.
# [('AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', Decimal('27.94017'), Decimal('-82.32547')),
#  ('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', Decimal('40.82624'), Decimal('-74.47995')),
#  ('ARGUVEV1187B98BA17', 'Sierra Maestra', '', None, None),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', Decimal('49.80388'), Decimal('15.47491')),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', Decimal('40.73197'), Decimal('-74.17418')),
#  ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', None, None),
#  ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', Decimal('32.67828'), Decimal('-83.22295')),
#  ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', Decimal('40.79195'), Decimal('-73.94512')),
#  ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', None, None),
# ...

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1542069637796, 0, 13, 46, 11, 2018, 1),
#  (1542071549796, 1, 13, 46, 11, 2018, 1),
#  (1542079142796, 3, 13, 46, 11, 2018, 1),
#  (1542081112796, 3, 13, 46, 11, 2018, 1),
#  (1542085206796, 5, 13, 46, 11, 2018, 1)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
